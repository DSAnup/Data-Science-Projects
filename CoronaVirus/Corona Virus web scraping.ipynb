# %%
from datetime import date
today = date.today()
d = today.strftime("%m-%d-%y")
print("date - ", d)
# Out:
# date -  03-20-20

# %%
cnn_url = "https://www.cnn.com/world/live-news/coronavirus-outbreak-{}-intl-hnk/index.html".format(d)

# %%
print(cnn_url)
# Out:
# https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html

# %%
from bs4 import BeautifulSoup
import requests

# %%
html = requests.get(cnn_url).text

# %%
soup = BeautifulSoup(html)
print(soup.title)
# Out:
# <title data-rh="true">Live updates: Coronavirus deaths top 10,000 globally - CNN</title>

# %%
#!pip install spacy && python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\anup\anaconda3\lib\site-packages (2.2.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (2.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (2.22.0)
# Requirement already satisfied: thinc==7.4.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (4.43.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (1.16.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (1.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (0.6.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: setuptools in c:\users\anup\anaconda3\lib\site-packages (from spacy) (41.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\anup\anaconda3\lib\site-packages (from spacy) (3.0.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\anup\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\anup\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\anup\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anup\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.9.11)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\anup\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy) (0.23)
# Requirement already satisfied: zipp>=0.5 in c:\users\anup\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (0.6.0)
# Requirement already satisfied: more-itertools in c:\users\anup\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (7.2.0)
# Collecting en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0MB)
# Requirement already satisfied: spacy>=2.2.2 in c:\users\anup\anaconda3\lib\site-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: thinc==7.4.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.6.0)
# Requirement already satisfied: setuptools in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (41.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.43.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.22.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.16.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\anup\anaconda3\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\anup\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\anup\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anup\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\anup\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\anup\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (0.23)
# Requirement already satisfied: zipp>=0.5 in c:\users\anup\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (0.6.0)
# Requirement already satisfied: more-itertools in c:\users\anup\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (7.2.0)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py): started
#   Building wheel for en-core-web-sm (setup.py): finished with status 'done'
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.2.5-cp37-none-any.whl size=12011744 sha256=d3b046bc324b56b9b37d4c0de72a4d71b800c273be222cde94cccdbc11318f6b
#   Stored in directory: C:\Users\Anup\AppData\Local\Temp\pip-ephem-wheel-cache-wm9f_vjb\wheels\6a\47\fb\6b5a0b8906d8e8779246c67d4658fd8a544d4a03a75520197a
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-2.2.5
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
for link in soup.find_all("h2"):
    print("Headline : {}".format(link.text))
    for ent in nlp(link.text).ents:
        print("\nText: {}, Entity : {}".format(ent.text, ent.label_))
# Out:
# Headline : What you need to know
# Headline : FDA allows expanded use of remote medical devices for health care workers
#
# Text: FDA, Entity : ORG
# Headline : UK government covers wages for virus-hit businesses
#
# Text: UK, Entity : GPE
# Headline : Italy announces 627 coronavirus deaths in 24 hours
#
# Text: Italy, Entity : GPE
#
# Text: 627, Entity : CARDINAL
#
# Text: 24 hours, Entity : TIME
# Headline : World Health Organization to young people: "You are not invincible"
#
# Text: World Health Organization, Entity : ORG
# Headline : Schumer: "At the moment, the McConnell bill is inadequate"
#
# Text: McConnell, Entity : ORG
# Headline : British pubs and restaurants asked to close due to coronavirus
#
# Text: British, Entity : NORP
# Headline : Pompeo says US will "use all the tools we can" to get US citizens abroad home
#
# Text: Pompeo, Entity : ORG
#
# Text: US, Entity : GPE
#
# Text: US, Entity : GPE
# Headline : 2 more TSA screeners in New York and Atlanta have tested positive
#
# Text: 2, Entity : CARDINAL
#
# Text: TSA, Entity : ORG
#
# Text: New York, Entity : GPE
#
# Text: Atlanta, Entity : GPE
# Headline : Federal Aviation Administration says JFK tower has re-opened after it closed for cleaning
#
# Text: Federal Aviation Administration, Entity : ORG
#
# Text: JFK tower, Entity : PERSON

# %%
nbc_url = 'https://www.nbcnews.com/health/coronavirus'
cnbc_rss_url = 'https://www.cnbc.com/id/10000108/device/rss/rss.html'

# %%
urls = [cnn_url, nbc_url, cnbc_rss_url]
formats = ['html.parser', 'html.parser', 'xml']
tags= ['h2', 'h2', 'description']
website = ['CNN', 'NBC', 'CNBC']

# %%
crawl_len = 0
for url in urls:
    print("Crawling web page ..... {}".format(url))
    response = requests.get(url)
    soup = BeautifulSoup(response.content, formats[crawl_len])
    
    for link in soup.find_all(tags[crawl_len]):
        
        if(len(link.text.split(" ")) > 4):
            print("Headline : {}".format(link.text))
            
            entities = []
            for ent in nlp(link.text).ents:
                print("\nText: {}, Entity : {}".format(ent.text, ent.label_))
                
    crawl_len = crawl_len + 1
# Out:
# Crawling web page ..... https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# Headline : What you need to know
# Headline : World Health Organization has distributed 1.5 million coronavirus lab tests around the world
#
# Text: World Health Organization, Entity : ORG
#
# Text: 1.5 million, Entity : CARDINAL
# Headline : World Health Organization urges "looking after your physical and mental health" during pandemic
#
# Text: World Health Organization, Entity : ORG
# Headline : Michigan suspends non-essential medical and dental procedures
#
# Text: Michigan, Entity : GPE
# Headline : Morocco repatriation flights for US citizens will continue this weekend, State Department official says
#
# Text: Morocco, Entity : GPE
#
# Text: US, Entity : GPE
#
# Text: this weekend, Entity : DATE
#
# Text: State Department, Entity : ORG
# Headline : More soldiers needed in Italy's hardest hit region to enforce emergency lockdown, governor says
#
# Text: Italy, Entity : GPE
# Headline : DC mayor announces first coronavirus death
# Headline : FDA allows expanded use of remote medical devices for health care workers
#
# Text: FDA, Entity : ORG
# Headline : UK government covers wages for virus-hit businesses
#
# Text: UK, Entity : GPE
# Headline : Italy announces 627 coronavirus deaths in 24 hours
#
# Text: Italy, Entity : GPE
#
# Text: 627, Entity : CARDINAL
#
# Text: 24 hours, Entity : TIME
# Crawling web page ..... https://www.nbcnews.com/health/coronavirus
# Headline : NY governor orders nonessential workforce to stay home; mayor says NYC will run out of medical supplies in weeks
#
# Text: NYC, Entity : ORG
#
# Text: weeks, Entity : DATE
# Headline : Live Blog / Latest news on the global pandemic
# Headline : U.K. shutters all pubs in bid to contain coronavirus outbreak
#
# Text: U.K., Entity : GPE
# Headline : 'Not for the worried well': Some coronavirus drive-thru test sites draw huge lines
# Headline : 'Open for business': Some popular Florida beaches refusing to close
#
# Text: Florida, Entity : GPE
# Headline : 'There have been a lot of tears': Coronavirus threatens to shut schools until the fall
#
# Text: Coronavirus, Entity : ORG
# Headline : Astronauts offer advice on keeping calm (and carrying on) amid coronavirus outbreak
# Headline : Job losses could quickly soar into the millions as coronavirus craters U.S. economy
#
# Text: the millions, Entity : CARDINAL
#
# Text: U.S., Entity : GPE
# Headline : Despite tax day extension, coronavirus restrictions still hobble tax payers and preparers
#
# Text: day, Entity : DATE
# Headline : Boris Johnson's libertarian views behind apparent hesitancy to lock down Britain
#
# Text: Boris Johnson's, Entity : PERSON
#
# Text: Britain, Entity : GPE
# Headline : As deliveries soar, UPS drivers say company's coronavirus precautions may not keep them or customers safe
# Headline : New Africa coronavirus crisis looms with internal spread
#
# Text: New Africa, Entity : GPE
# Headline : Communities rally around one another — and Google Docs — to bring coronavirus aid
#
# Text: Google Docs, Entity : PERSON
# Headline : Is spring break over? Local Florida officials close beaches after gov refuses to.
#
# Text: Florida, Entity : GPE
# Headline : For people with anxiety and OCD, coronavirus is a 'personal nightmare'
#
# Text: OCD, Entity : ORG
# Headline : Coronavirus uncertainty bites as London pubs, restaurants consider shutting
#
# Text: Coronavirus, Entity : ORG
#
# Text: London, Entity : GPE
# Headline : After pressure, Trump coronavirus guide is in Spanish on CDC, White House sites
#
# Text: Trump, Entity : PRODUCT
#
# Text: Spanish, Entity : LANGUAGE
#
# Text: CDC, Entity : ORG
#
# Text: White House, Entity : ORG
# Headline : Trump planning new restrictions on U.S.-Mexico travel
# Headline : Senate GOP unveils massive coronavirus bill that includes checks for Americans
#
# Text: Senate, Entity : ORG
#
# Text: GOP, Entity : ORG
#
# Text: Americans, Entity : NORP
# Headline : Washington's trillion-dollar coronavirus fix may be too little, too late
#
# Text: Washington, Entity : GPE
#
# Text: trillion-dollar, Entity : MONEY
# Headline : Companies are rushing to introduce coronavirus testing kits — and so are scam artists
# Headline : Americans stuck in Peru over coronavirus fears urge U.S. to bring them home
#
# Text: Americans, Entity : NORP
#
# Text: Peru, Entity : GPE
#
# Text: U.S., Entity : GPE
# Headline : Stress eating won't help. Use this routine to stay healthy while you're stuck at home.
# Headline : Trump nixed harsh response to attacks by Iranian proxies because of coronavirus, officials say
#
# Text: Iranian, Entity : NORP
# Headline : Coronavirus hits adults of all ages and those with chronic health problems
#
# Text: Coronavirus, Entity : ORG
# Headline : U.S. restricts visas for farmworkers, raising concerns about food supply
#
# Text: U.S., Entity : GPE
# Headline : Daniel Dae Kim announces he has coronavirus
#
# Text: Daniel Dae Kim, Entity : PERSON
# Headline : Markets close with modest gains amid rising economic toll
# Headline : State Department warns Americans not to travel because of coronavirus
#
# Text: State Department, Entity : ORG
#
# Text: Americans, Entity : NORP
# Headline : Wuhan study offers new insight into fatality rate of coronavirus
#
# Text: Wuhan, Entity : GPE
# Headline : Italy's coronavirus death toll overtakes China's
#
# Text: Italy, Entity : GPE
#
# Text: China, Entity : GPE
# Headline : American released from Iranian prison on medical furlough amid coronavirus outbreak
#
# Text: American, Entity : NORP
#
# Text: Iranian, Entity : NORP
# Headline : Experimental drug holds promise for treating the coronavirus
# Headline : Coronavirus could lead to 25 million layoffs, U.N. labor organization says
#
# Text: Coronavirus, Entity : ORG
#
# Text: 25 million, Entity : CARDINAL
#
# Text: U.N., Entity : ORG
# Headline : Politicians, journalists, celebrities call out racist remarks against Asians
#
# Text: Asians, Entity : NORP
# Headline : Monaco's Prince Albert II tests positive for coronavirus
#
# Text: Monaco, Entity : GPE
# Headline : Lawmakers urge Trump admin to protect those with HIV amid coronavirus pandemic
#
# Text: Trump, Entity : PRODUCT
# Headline : NBA commissioner defends coronavirus testing of players without symptoms
#
# Text: NBA, Entity : ORG
# Headline : Coronavirus stimulus checks: What you need to know
#
# Text: Coronavirus, Entity : ORG
# Headline : 'Puerto Rico is no one's priority' amid coronavirus pandemic, experts say
#
# Text: Puerto Rico, Entity : GPE
# Headline : Behind the urge to stockpile: First masks, then toilet paper, now cash?
#
# Text: First, Entity : ORDINAL
# Headline : Hospitals sound alarm on funding for supplies to treat patients, protect workers
# Headline : Millions of Americans will soon run out of money. Here's how to deal with bills you can't pay.
#
# Text: Millions, Entity : CARDINAL
#
# Text: Americans, Entity : NORP
# Headline : Coronavirus forces hospitals to prepare for life-or-death decisions
#
# Text: Coronavirus, Entity : ORG
# Headline : China reports no new coronavirus cases, offers medical aid overseas
#
# Text: China, Entity : GPE
# Headline : In NYC, Latino restaurant owners struggle amid coronavirus crisis
#
# Text: NYC, Entity : ORG
#
# Text: Latino, Entity : PERSON
# Headline : Two members of House test positive for COVID-19
#
# Text: Two, Entity : CARDINAL
#
# Text: House, Entity : ORG
# Headline : U.S. called on to close immigration courts, release some detainees
#
# Text: U.S., Entity : GPE
# Headline : Coronavirus outbreak revives dangerous race myths and pseudoscience
#
# Text: Coronavirus, Entity : ORG
# Headline : Here are 3 drugs in development to fight coronavirus, 2 vaccines and one 'passive' vaccine
#
# Text: 3, Entity : CARDINAL
#
# Text: 2, Entity : CARDINAL
#
# Text: one, Entity : CARDINAL
# Headline : 'The health system is already in shambles': Venezuela's hidden COVID-19 crisis
#
# Text: Venezuela, Entity : GPE
# Headline : Coronavirus could cause 'carnage' among the world's refugees, aid groups say
#
# Text: Coronavirus, Entity : ORG
# Headline : Watch NBC's special report: Coronavirus pandemic
#
# Text: NBC, Entity : ORG
#
# Text: Coronavirus, Entity : ORG
# Headline : Italy has a world-class health system. The coronavirus has pushed it to the breaking point.
#
# Text: Italy, Entity : GPE
# Headline : 'No heart. No understanding': During coronavirus, renters face eviction uncertainty
# Headline : In just days, lockdown provides vivid picture of how environment recovers without people
#
# Text: just days, Entity : DATE
# Headline : Coronavirus: What you need to know
# Headline : Photos capture empty cities across the globe
# Headline : Trump signs off on coronavirus aid bill
# Headline : 'Everything is out of our control': San Francisco eases into lockdown
#
# Text: San Francisco, Entity : GPE
# Headline : NAACP's virtual town hall confronts impact of coronavirus on people of color
#
# Text: NAACP, Entity : ORG
# Headline : Trump says it may be 'the story of life' that well-connected get coronavirus testing first
#
# Text: Trump, Entity : PERSON
#
# Text: first, Entity : ORDINAL
# Headline : Sen. Cornyn: China to blame for coronavirus, because 'people eat bats'
#
# Text: Cornyn, Entity : PERSON
#
# Text: China, Entity : GPE
# Headline : Trump doubles down that he's not fueling racism, but experts say he is
#
# Text: Trump, Entity : PRODUCT
# Headline : Celebrities flock to Instagram Live during social distancing
#
# Text: Instagram Live, Entity : WORK_OF_ART
# Headline : Some states looking to vote by mail as coronavirus spreads
# Headline : Florida governor refuses to shut down beaches amid spread of coronavirus
# Text: Florida, Entity : GPE
# Headline : He doesn't have coronavirus. It could kill him anyway.
# Headline : Dow closes with loss of 1,300 points as coronavirus fears take hold
#
# Text: 1,300, Entity : CARDINAL
# Crawling web page ..... https://www.cnbc.com/id/10000108/device/rss/rss.html
# Headline : Latest news for health care.
# Headline : The private-jet industry is asking Congress for bailout money, even as many private jet companies say sales are strong as wealthy flyers avoid commercial flights.
#
# Text: Congress, Entity : ORG
# Headline : U.K. Finance Minister Rishi Sunak announced the government would pay 80% of wages for employees who are unable to work — up to 2,500 pounds a month.
#
# Text: U.K., Entity : GPE
#
# Text: Rishi Sunak, Entity : PERSON
#
# Text: 80%, Entity : PERCENT
#
# Text: up to 2,500 pounds, Entity : MONEY
# Headline : World Health Organization officials are holding a press conference to update the public on the coronavirus outbreak.
#
# Text: World Health Organization, Entity : ORG
# Headline : Microsoft, Adaptive Biotechnologies, Illumina and other companies are partnering on a project to map out how the human immune system responds to the virus. Most efforts, they say, are focused on the biology of the virus.
#
# Text: Microsoft, Entity : ORG
#
# Text: Adaptive Biotechnologies, Entity : ORG
#
# Text: Illumina, Entity : GPE
# Headline : Robert Herjavec, cybersecurity entrepreneur and "Shark Tank" investor, told CNBC that his directive to small businesses is to do whatever it takes to survive.
#
# Text: Robert Herjavec, Entity : PERSON
#
# Text: Shark Tank, Entity : WORK_OF_ART
#
# Text: CNBC, Entity : ORG
# Headline : Members of President Donald Trump's coronavirus task force hold a press briefing Friday at the White House as authorities on the local, state and federal levels take drastic measures to slow the spread of the disease.
#
# Text: Donald Trump, Entity : PERSON
#
# Text: Friday, Entity : DATE
#
# Text: the White House, Entity : FAC
# Headline : Gov. Andrew Cuomo ordered nonessential businesses to keep 100% of their workforce at home and put in place stringent new restrictions.
#
# Text: Andrew Cuomo, Entity : PERSON
#
# Text: 100%, Entity : PERCENT
# Headline : The coronavirus has infected more than 5,000 people in the state.
#
# Text: more than 5,000, Entity : CARDINAL
# Headline : So many groups have popped up in the past five days that there are now master spreadsheets circulating on Twitter, Nextdoor and Facebook, NBC News reports.
#
# Text: the past five days, Entity : DATE
#
# Text: NBC News, Entity : ORG
# Headline : Most people in Spain's capital city will get the coronavirus, according to the head of the Madrid region.
#
# Text: Spain, Entity : GPE
#
# Text: Madrid, Entity : GPE
# Headline : "It's going to take a good month or so to recruit our teams back and to get train them, trained before we could serve like we used to," restaurateur Danny Meyer said told CNBC.
#
# Text: a good month or so, Entity : DATE
#
# Text: Danny Meyer, Entity : PERSON
#
# Text: CNBC, Entity : ORG
# Headline : European banks are under intense pressure as the coronavirus halts all major economies, at a time when these institutions were still struggling with the legacy issues of the 2008 financial crash.
#
# Text: European, Entity : NORP
#
# Text: 2008, Entity : DATE
# Headline : The program is designed to accelerate diagnostic solutions for coronavirus COVID-19 and other infectious diseases.
# Headline : The company announced on March 3 an accelerated share repurchase agreement (ASR agreement) with Morgan Stanley to repurchase $4 billion worth of common stock in its fiscal second quarter. Shares of AT&T closed Thursday at $31.15 per share.
#
# Text: March 3, Entity : DATE
#
# Text: Morgan Stanley, Entity : ORG
#
# Text: $4 billion, Entity : MONEY
#
# Text: its fiscal second quarter, Entity : DATE
#
# Text: AT&T, Entity : ORG
#
# Text: Thursday, Entity : DATE
#
# Text: 31.15, Entity : MONEY
# Headline : As of Friday, more than 254,000 cases of coronavirus have been reported, resulting in at least 10,000 deaths.
#
# Text: Friday, Entity : DATE
#
# Text: more than 254,000, Entity : CARDINAL
#
# Text: at least 10,000, Entity : CARDINAL
# Headline : Dow futures point to more gains at Friday's open on Wall Street. Nasdaq futures hit 5% "limit up."
#
# Text: Friday, Entity : DATE
#
# Text: 5%, Entity : PERCENT
# Headline : Airlines are pretty much facing a cashflow and liquidity crisis due to the global coronavirus outbreak and need government support, said Joanna Lu of Ascend by Cirium.
#
# Text: Joanna Lu, Entity : PERSON
# Headline : Climate scientists have been calling for governments to take climate action seriously for decades.
#
# Text: decades, Entity : DATE
# Headline : As people across the globe adjust to prolonged periods of quarantine, CNBC Make It spoke to psychology experts to find out how people can protect their mental health.
#
# Text: CNBC, Entity : ORG
# Headline : The coronavirus pandemic has exposed the vulnerability of countries and companies that rely heavily on a limited number of partners for their business needs.
# Headline : The company this week announced free premium membership to viewers in France and Spain, after doing the same for Italy a week prior.
#
# Text: this week, Entity : DATE
#
# Text: France, Entity : GPE
#
# Text: Spain, Entity : GPE
#
# Text: Italy, Entity : GPE
# Headline : Businesses including condom-makers, gin producers and food manufacturers are seeing consumers react in different ways as they self-isolate or reduce social contact.
# Headline : The bounce in cryptocurrency prices followed two violent bouts of selling.
#
# Text: two, Entity : CARDINAL
# Headline : Los Angeles Mayor Eric Garcetti on Thursday issued a "Safer at Home" order, asking residents to stay home and limit all "non essential activities."
#
# Text: Los Angeles, Entity : GPE
#
# Text: Eric Garcetti, Entity : PERSON
#
# Text: Thursday, Entity : DATE
#
# Text: Safer at Home, Entity : WORK_OF_ART
# Headline : Los Angeles issued a "Safer at Home" emergency order, meaning residents must "immediately limit all movement outside of their homes beyond what is absolutely essential," Mayor Eric Garcetti said.
#
# Text: Los Angeles, Entity : GPE
#
# Text: Safer at Home, Entity : WORK_OF_ART
#
# Text: Eric Garcetti, Entity : PERSON
# Headline : "In the last 24 hours, we had 126 new COVID-19 cases, a 21 percent increase. In some parts of our state, our case rate is doubling every four days," Newsom wrote in a letter dated Wednesday.
#
# Text: the last 24 hours, Entity : TIME
#
# Text: 126, Entity : CARDINAL
#
# Text: 21 percent, Entity : PERCENT
#
# Text: every four days, Entity : DATE
#
# Text: Newsom, Entity : PERSON
#
# Text: Wednesday, Entity : DATE
# Headline : Sick patients are being turned away, unable to receive tests because they simply aren't available. In a stark contrast, the NBA said that as of Wednesday, at least eight teams had been tested for the COVID-19 coronavirus.
#
# Text: NBA, Entity : ORG
#
# Text: Wednesday, Entity : DATE
#
# Text: at least eight, Entity : CARDINAL
# Headline : While reporting on the pandemic from Beijing for the past eight weeks, CNBC's Eunice Yoon has been living under a lockdown.
#
# Text: Beijing, Entity : GPE
#
# Text: the past eight weeks, Entity : DATE
#
# Text: CNBC, Entity : ORG
#
# Text: Eunice Yoon, Entity : PERSON
# Headline : The number of infections in New York City jumped by more than 1,000 cases in a matter of hours — since Thursday morning when Gov. Andrew Cuomo said there were 2,469 infections in the city.
#
# Text: New York City, Entity : GPE
#
# Text: more than 1,000, Entity : CARDINAL
#
# Text: hours, Entity : TIME
#
# Text: Thursday, Entity : DATE
#
# Text: morning, Entity : TIME
#
# Text: Andrew Cuomo, Entity : PERSON
#
# Text: 2,469, Entity : CARDINAL
# Headline : The company said it began testing firefighters and other first responders for the coronavirus Thursday in Shrewsbury, Massachusetts.
#
# Text: first, Entity : ORDINAL
#
# Text: Thursday, Entity : DATE
#
# Text: Shrewsbury, Entity : GPE
#
# Text: Massachusetts, Entity : GPE

# %%
crawl_len = 0
news_dict = []
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, formats[crawl_len])
    
    for link in soup.find_all(tags[crawl_len]):
        
        if(len(link.text.split(" ")) > 4):
            
            entities = []
            
            entities = [(ent.text, ent.label_) for ent in nlp(link.text).ents]
            
            news_dict.append({'website': website[crawl_len], 'url': url, 'headline': link.text, 'entities': entities})
    crawl_len = crawl_len + 1

# %%
news_dict
# Out:
# [{'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': 'What you need to know',
#   'entities': []},
#  {'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': 'US\xa0businesses\xa0will suffer a\xa0$4 trillion\xa0decline due to coronavirus, hedge fund predicts',
#   'entities': [('US', 'GPE'), ('$4 trillion', 'MONEY')]},
#  {'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': 'World Health Organization has distributed 1.5 million coronavirus lab tests around the world',
#   'entities': [('World Health Organization', 'ORG'),
#    ('1.5 million', 'CARDINAL')]},
#  {'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': 'World Health Organization urges "looking after your physical and mental health" during pandemic',
#   'entities': [('World Health Organization', 'ORG')]},
#  {'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': 'Michigan suspends non-essential medical and dental procedures',
#   'entities': [('Michigan', 'GPE')]},
#  {'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': 'Morocco repatriation flights for US citizens will continue this weekend, State Department official says',
#   'entities': [('Morocco', 'GPE'),
#    ('US', 'GPE'),
#    ('this weekend', 'DATE'),
#    ('State Department', 'ORG')]},
#  {'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': "More soldiers needed in Italy's hardest hit region to enforce emergency lockdown, governor says",
#   'entities': [('Italy', 'GPE')]},
#  {'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': 'DC mayor announces first coronavirus death',
#   'entities': []},
#  {'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': 'FDA allows expanded use of remote medical devices for health care workers',
#   'entities': [('FDA', 'ORG')]},
#  {'website': 'CNN',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html',
#   'headline': 'UK government covers wages for virus-hit businesses',
#   'entities': [('UK', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'NY governor orders nonessential workforce to stay home; mayor says NYC will run out of medical supplies in weeks',
#   'entities': [('NYC', 'ORG'), ('weeks', 'DATE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Live Blog\xa0/ Latest news on the global pandemic',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'U.K. shutters all pubs in bid to contain coronavirus outbreak',
#   'entities': [('U.K.', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'Not for the worried well': Some coronavirus drive-thru test sites draw huge lines",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'Open for business': Some popular Florida beaches refusing to close",
#   'entities': [('Florida', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'There have been a lot of tears': Coronavirus threatens to shut schools until the fall",
#   'entities': [('Coronavirus', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Astronauts offer advice on keeping calm (and carrying on) amid coronavirus outbreak',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Job losses could quickly soar into the millions as coronavirus craters U.S. economy',
#   'entities': [('the millions', 'CARDINAL'), ('U.S.', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Despite tax day extension, coronavirus restrictions still hobble tax payers and preparers',
#   'entities': [('day', 'DATE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Boris Johnson's libertarian views behind apparent hesitancy to lock down Britain",
#   'entities': [("Boris Johnson's", 'PERSON'), ('Britain', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "As deliveries soar, UPS drivers say company's coronavirus precautions may not keep them or customers safe",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'New Africa coronavirus crisis looms with internal spread',
#   'entities': [('New Africa', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Communities rally around one another — and Google Docs — to bring coronavirus aid',
#   'entities': [('Google Docs', 'PERSON')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Is spring break over? Local Florida officials close beaches after gov refuses to.',
#   'entities': [('Florida', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "For people with anxiety and OCD, coronavirus is a 'personal nightmare'",
#   'entities': [('OCD', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Coronavirus uncertainty bites as London pubs, restaurants consider shutting',
#   'entities': [('Coronavirus', 'ORG'), ('London', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'After pressure, Trump coronavirus guide is in Spanish on CDC, White House sites',
#   'entities': [('Trump', 'PRODUCT'),
#    ('Spanish', 'LANGUAGE'),
#    ('CDC', 'ORG'),
#    ('White House', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Trump planning new restrictions on U.S.-Mexico travel',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Senate GOP unveils massive coronavirus bill that includes checks for Americans',
#   'entities': [('Senate', 'ORG'), ('GOP', 'ORG'), ('Americans', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Washington's trillion-dollar coronavirus fix may be too little, too late",
#   'entities': [('Washington', 'GPE'), ('trillion-dollar', 'MONEY')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Companies are rushing to introduce coronavirus testing kits — and so are scam artists',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Americans stuck in Peru over coronavirus fears urge U.S. to bring them home',
#   'entities': [('Americans', 'NORP'), ('Peru', 'GPE'), ('U.S.', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Stress eating won't help. Use this routine to stay healthy while you're stuck at home.",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Trump nixed harsh response to attacks by Iranian proxies because of coronavirus, officials say',
#   'entities': [('Iranian', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Coronavirus hits adults of all ages and those with chronic health problems',
#   'entities': [('Coronavirus', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'U.S. restricts visas for farmworkers, raising concerns about food supply',
#   'entities': [('U.S.', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Daniel Dae Kim announces he has coronavirus',
#   'entities': [('Daniel Dae Kim', 'PERSON')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Markets close with modest gains amid rising economic toll',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'State Department warns Americans not to travel because of coronavirus',
#   'entities': [('State Department', 'ORG'), ('Americans', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Wuhan study offers new insight into fatality rate of coronavirus',
#   'entities': [('Wuhan', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Italy's coronavirus death toll overtakes China's",
#   'entities': [('Italy', 'GPE'), ('China', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'American released from Iranian prison on medical furlough amid coronavirus outbreak',
#   'entities': [('American', 'NORP'), ('Iranian', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Experimental drug holds promise for treating the coronavirus',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Coronavirus could lead to 25 million layoffs, U.N. labor organization says',
#   'entities': [('Coronavirus', 'ORG'),
#    ('25 million', 'CARDINAL'),
#    ('U.N.', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Politicians, journalists, celebrities call out racist remarks against Asians',
#   'entities': [('Asians', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Monaco's Prince Albert II tests positive for coronavirus",
#   'entities': [('Monaco', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Lawmakers urge Trump admin to protect those with HIV amid coronavirus pandemic',
#   'entities': [('Trump', 'PRODUCT')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'NBA commissioner defends coronavirus testing of players without symptoms',
#   'entities': [('NBA', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Coronavirus stimulus checks: What you need to know',
#   'entities': [('Coronavirus', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'Puerto Rico is no one's priority' amid coronavirus pandemic, experts say",
#   'entities': [('Puerto Rico', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Behind the urge to stockpile: First masks, then toilet paper, now cash?',
#   'entities': [('First', 'ORDINAL')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Hospitals sound alarm on funding for supplies to treat patients, protect workers',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Millions of Americans will soon run out of money. Here's how to deal with bills you can't pay.",
#   'entities': [('Millions', 'CARDINAL'), ('Americans', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Coronavirus forces hospitals to prepare for life-or-death decisions',
#   'entities': [('Coronavirus', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'China reports no new coronavirus cases, offers medical aid overseas',
#   'entities': [('China', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'In NYC, Latino restaurant owners struggle amid coronavirus crisis',
#   'entities': [('NYC', 'ORG'), ('Latino', 'PERSON')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Two members of House test positive for COVID-19',
#   'entities': [('Two', 'CARDINAL'), ('House', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'U.S. called on to close immigration courts, release some detainees',
#   'entities': [('U.S.', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Coronavirus outbreak revives dangerous race myths and pseudoscience',
#   'entities': [('Coronavirus', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Here are 3 drugs in development to fight coronavirus, 2 vaccines and one 'passive' vaccine",
#   'entities': [('3', 'CARDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'The health system is already in shambles': Venezuela's hidden COVID-19 crisis",
#   'entities': [('Venezuela', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Coronavirus could cause 'carnage' among the world's refugees, aid groups say",
#   'entities': [('Coronavirus', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Watch NBC's special report: Coronavirus pandemic",
#   'entities': [('NBC', 'ORG'), ('Coronavirus', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Italy has a world-class health system. The coronavirus has pushed it to the breaking point.',
#   'entities': [('Italy', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'No heart. No understanding': During coronavirus, renters face eviction uncertainty",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'In just days, lockdown provides vivid picture of how environment recovers without people',
#   'entities': [('just days', 'DATE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Coronavirus: What you need to know',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Photos capture empty cities across the globe',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Trump signs off on coronavirus aid bill',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'Everything is out of our control': San Francisco eases into lockdown",
#   'entities': [('San Francisco', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "NAACP's virtual town hall confronts impact of coronavirus on people of color",
#   'entities': [('NAACP', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Trump says it may be 'the story of life' that well-connected get coronavirus testing first",
#   'entities': [('Trump', 'PERSON'), ('first', 'ORDINAL')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Sen. Cornyn: China to blame for coronavirus, because 'people eat bats'",
#   'entities': [('Cornyn', 'PERSON'), ('China', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Trump doubles down that he's not fueling racism, but experts say he is",
#   'entities': [('Trump', 'PRODUCT')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Celebrities flock to Instagram Live during social distancing',
#   'entities': [('Instagram Live', 'WORK_OF_ART')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Some states looking to vote by mail as coronavirus spreads',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Florida governor refuses to shut down beaches amid spread of coronavirus',
#   'entities': [('Florida', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "He doesn't have coronavirus. It could kill him anyway.",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Dow closes with loss of 1,300 points as coronavirus fears take hold',
#   'entities': [('1,300', 'CARDINAL')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Latest news for health care. ',
#   'entities': []},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'On Thursday, the number of people who have died from COVID-19 in Italy surpassed that of China.',
#   'entities': [('Thursday', 'DATE'), ('Italy', 'GPE'), ('China', 'GPE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The private-jet industry is asking Congress for bailout money, even as many private jet companies say sales are strong as wealthy flyers avoid commercial flights.',
#   'entities': [('Congress', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'U.K. Finance Minister Rishi Sunak announced the government would pay 80% of wages for employees who are unable to work — up to 2,500 pounds a month.',
#   'entities': [('U.K.', 'GPE'),
#    ('Rishi Sunak', 'PERSON'),
#    ('80%', 'PERCENT'),
#    ('up to 2,500 pounds', 'MONEY')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'World Health Organization officials are holding a press conference to update the public on the coronavirus outbreak.',
#   'entities': [('World Health Organization', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Microsoft, Adaptive Biotechnologies, Illumina and other companies are partnering on a project to map out how the human immune system responds to the virus. Most efforts, they say, are focused on the biology of the virus.',
#   'entities': [('Microsoft', 'ORG'),
#    ('Adaptive Biotechnologies', 'ORG'),
#    ('Illumina', 'GPE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Robert Herjavec, cybersecurity entrepreneur and "Shark Tank" investor, told CNBC that his directive to small businesses is to do whatever it takes to survive.',
#   'entities': [('Robert Herjavec', 'PERSON'),
#    ('Shark Tank', 'WORK_OF_ART'),
#    ('CNBC', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "Members of President Donald Trump's coronavirus task force hold a press briefing Friday at the White House as authorities on the local, state and federal levels take drastic measures to slow the spread of the disease.",
#   'entities': [('Donald Trump', 'PERSON'),
#    ('Friday', 'DATE'),
#    ('the White House', 'FAC')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Gov. Andrew Cuomo ordered nonessential businesses to keep 100% of their workforce at home and put in place stringent new restrictions.',
#   'entities': [('Andrew Cuomo', 'PERSON'), ('100%', 'PERCENT')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The coronavirus has infected more than 5,000 people in the state.',
#   'entities': [('more than 5,000', 'CARDINAL')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'So many groups have popped up in the past five days that there are now master spreadsheets circulating on Twitter, Nextdoor and Facebook, NBC News reports.',
#   'entities': [('the past five days', 'DATE'), ('NBC News', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "Most people in Spain's capital city will get the coronavirus, according to the head of the Madrid region.",
#   'entities': [('Spain', 'GPE'), ('Madrid', 'GPE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': '"It\'s going to take a good month or so to recruit our teams back and to get train them, trained before we could serve like we used to," restaurateur Danny Meyer said told CNBC.',
#   'entities': [('a good month or so', 'DATE'),
#    ('Danny Meyer', 'PERSON'),
#    ('CNBC', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'European banks are under intense pressure as the coronavirus halts all major economies, at a time when these institutions were still struggling with the legacy issues of the 2008 financial crash.',
#   'entities': [('European', 'NORP'), ('2008', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The program is designed to accelerate diagnostic solutions for coronavirus COVID-19 and other infectious diseases.',
#   'entities': []},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The company announced on March 3 an accelerated share repurchase agreement (ASR agreement) with Morgan Stanley to repurchase $4 billion worth of common stock in its fiscal second quarter. Shares of AT&T closed Thursday at $31.15 per share.',
#   'entities': [('March 3', 'DATE'),
#    ('Morgan Stanley', 'ORG'),
#    ('$4 billion', 'MONEY'),
#    ('its fiscal second quarter', 'DATE'),
#    ('AT&T', 'ORG'),
#    ('Thursday', 'DATE'),
#    ('31.15', 'MONEY')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'As of Friday, more than 254,000 cases of coronavirus have been reported, resulting in at least 10,000 deaths.',
#   'entities': [('Friday', 'DATE'),
#    ('more than 254,000', 'CARDINAL'),
#    ('at least 10,000', 'CARDINAL')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Dow futures point to more gains at Friday\'s open on Wall Street. Nasdaq futures hit 5% "limit up."',
#   'entities': [('Friday', 'DATE'), ('5%', 'PERCENT')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Airlines are pretty much facing a cashflow and liquidity crisis due to the global coronavirus outbreak and need government support, said Joanna Lu of Ascend by Cirium.',
#   'entities': [('Joanna Lu', 'PERSON')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Climate scientists have been calling for governments to take climate action seriously for decades.',
#   'entities': [('decades', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'As people across the globe adjust to prolonged periods of quarantine, CNBC Make It spoke to psychology experts to find out how people can protect their mental health.',
#   'entities': [('CNBC', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The coronavirus pandemic has exposed the vulnerability of countries and companies that rely heavily on a limited number of partners for their business needs.',
#   'entities': []},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The company this week announced free premium membership to viewers in France and Spain, after doing the same for Italy a week prior.',
#   'entities': [('this week', 'DATE'),
#    ('France', 'GPE'),
#    ('Spain', 'GPE'),
#    ('Italy', 'GPE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Businesses including condom-makers, gin producers and food manufacturers are seeing consumers react in different ways as they self-isolate or reduce social contact.',
#   'entities': []},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The bounce in cryptocurrency prices followed two violent bouts of selling.',
#   'entities': [('two', 'CARDINAL')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Los Angeles Mayor Eric Garcetti on Thursday issued a "Safer at Home" order, asking residents to stay home and limit all "non essential activities."',
#   'entities': [('Los Angeles', 'GPE'),
#    ('Eric Garcetti', 'PERSON'),
#    ('Thursday', 'DATE'),
#    ('Safer at Home', 'WORK_OF_ART')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Los Angeles issued a "Safer at Home" emergency order, meaning residents must "immediately limit all movement outside of their homes beyond what is absolutely essential," Mayor Eric Garcetti said.',
#   'entities': [('Los Angeles', 'GPE'),
#    ('Safer at Home', 'WORK_OF_ART'),
#    ('Eric Garcetti', 'PERSON')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': '"In the last 24 hours, we had 126 new COVID-19 cases, a 21 percent increase. In some parts of our state, our case rate is doubling every four days," Newsom wrote in a letter dated Wednesday.',
#   'entities': [('the last 24 hours', 'TIME'),
#    ('126', 'CARDINAL'),
#    ('21 percent', 'PERCENT'),
#    ('every four days', 'DATE'),
#    ('Newsom', 'PERSON'),
#    ('Wednesday', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "Sick patients are being turned away, unable to receive tests because they simply aren't available. In a stark contrast, the NBA said that as of Wednesday, at least eight teams had been tested for the COVID-19 coronavirus.",
#   'entities': [('NBA', 'ORG'),
#    ('Wednesday', 'DATE'),
#    ('at least eight', 'CARDINAL')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "While reporting on the pandemic from Beijing for the past eight weeks, CNBC's Eunice Yoon has been living under a lockdown.",
#   'entities': [('Beijing', 'GPE'),
#    ('the past eight weeks', 'DATE'),
#    ('CNBC', 'ORG'),
#    ('Eunice Yoon', 'PERSON')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The number of infections in New York City jumped by more than 1,000 cases in a matter of hours — since Thursday morning when Gov. Andrew Cuomo said there were 2,469 infections in the city.',
#   'entities': [('New York City', 'GPE'),
#    ('more than 1,000', 'CARDINAL'),
#    ('hours', 'TIME'),
#    ('Thursday', 'DATE'),
#    ('morning', 'TIME'),
#    ('Andrew Cuomo', 'PERSON'),
#    ('2,469', 'CARDINAL')]}]

# %%
import pandas as pd

# %%
news_df = pd.DataFrame(news_dict)

# %%
pd.set_option('max_colwidth', 800)

# %%
news_df.head(20)
# Out:
#    website  \
# 0      CNN
# 1      CNN
# 2      CNN
# 3      CNN
# 4      CNN
# 5      CNN
# 6      CNN
# 7      CNN
# 8      CNN
# 9      CNN
# 10     NBC
# 11     NBC
# 12     NBC
# 13     NBC
# 14     NBC
# 15     NBC
# 16     NBC
# 17     NBC
# 18     NBC
# 19     NBC
#
#                                                                                       url  \
# 0   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 1   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 2   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 3   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 4   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 5   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 6   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 7   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 8   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 9   https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 10                                             https://www.nbcnews.com/health/coronavirus
# 11                                             https://www.nbcnews.com/health/coronavirus
# 12                                             https://www.nbcnews.com/health/coronavirus
# 13                                             https://www.nbcnews.com/health/coronavirus
# 14                                             https://www.nbcnews.com/health/coronavirus
# 15                                             https://www.nbcnews.com/health/coronavirus
# 16                                             https://www.nbcnews.com/health/coronavirus
# 17                                             https://www.nbcnews.com/health/coronavirus
# 18                                             https://www.nbcnews.com/health/coronavirus
# 19                                             https://www.nbcnews.com/health/coronavirus
#
#                                                                                                             headline  \
# 0                                                                                              What you need to know
# 1                            US businesses will suffer a $4 trillion decline due to coronavirus, hedge fund predicts
# 2                       World Health Organization has distributed 1.5 million coronavirus lab tests around the world
# 3                    World Health Organization urges "looking after your physical and mental health" during pandemic
# 4                                                      Michigan suspends non-essential medical and dental procedures
# 5            Morocco repatriation flights for US citizens will continue this weekend, State Department official says
# 6                    More soldiers needed in Italy's hardest hit region to enforce emergency lockdown, governor says
# 7                                                                         DC mayor announces first coronavirus death
# 8                                          FDA allows expanded use of remote medical devices for health care workers
# 9                                                                UK government covers wages for virus-hit businesses
# 10  NY governor orders nonessential workforce to stay home; mayor says NYC will run out of medical supplies in weeks
# 11                                                                    Live Blog / Latest news on the global pandemic
# 12                                                     U.K. shutters all pubs in bid to contain coronavirus outbreak
# 13                                'Not for the worried well': Some coronavirus drive-thru test sites draw huge lines
# 14                                               'Open for business': Some popular Florida beaches refusing to close
# 15                            'There have been a lot of tears': Coronavirus threatens to shut schools until the fall
# 16                               Astronauts offer advice on keeping calm (and carrying on) amid coronavirus outbreak
# 17                               Job losses could quickly soar into the millions as coronavirus craters U.S. economy
# 18                         Despite tax day extension, coronavirus restrictions still hobble tax payers and preparers
# 19                                  Boris Johnson's libertarian views behind apparent hesitancy to lock down Britain
#
#                                                                       entities
# 0                                                                           []
# 1                                            [(US, GPE), ($4 trillion, MONEY)]
# 2                  [(World Health Organization, ORG), (1.5 million, CARDINAL)]
# 3                                           [(World Health Organization, ORG)]
# 4                                                            [(Michigan, GPE)]
# 5   [(Morocco, GPE), (US, GPE), (this weekend, DATE), (State Department, ORG)]
# 6                                                               [(Italy, GPE)]
# 7                                                                           []
# 8                                                                 [(FDA, ORG)]
# 9                                                                  [(UK, GPE)]
# 10                                                 [(NYC, ORG), (weeks, DATE)]
# 11                                                                          []
# 12                                                               [(U.K., GPE)]
# 13                                                                          []
# 14                                                            [(Florida, GPE)]
# 15                                                        [(Coronavirus, ORG)]
# 16                                                                          []
# 17                                     [(the millions, CARDINAL), (U.S., GPE)]
# 18                                                               [(day, DATE)]
# 19                                 [(Boris Johnson's, PERSON), (Britain, GPE)]

# %%
pd.concat([news_df[['website', 'url', 'headline']], news_df['entities'].apply(pd.Series)], axis = 1)
# Out:
#     website  \
# 0       CNN
# 1       CNN
# 2       CNN
# 3       CNN
# 4       CNN
# ..      ...
# 105    CNBC
# 106    CNBC
# 107    CNBC
# 108    CNBC
# 109    CNBC
#
#                                                                                        url  \
# 0    https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 1    https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 2    https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 3    https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# 4    https://www.cnn.com/world/live-news/coronavirus-outbreak-03-20-20-intl-hnk/index.html
# ..                                                                                     ...
# 105                                   https://www.cnbc.com/id/10000108/device/rss/rss.html
# 106                                   https://www.cnbc.com/id/10000108/device/rss/rss.html
# 107                                   https://www.cnbc.com/id/10000108/device/rss/rss.html
# 108                                   https://www.cnbc.com/id/10000108/device/rss/rss.html
# 109                                   https://www.cnbc.com/id/10000108/device/rss/rss.html
#
#                                                                                                                                                                                                                           headline  \
# 0                                                                                                                                                                                                            What you need to know
# 1                                                                                                                                          US businesses will suffer a $4 trillion decline due to coronavirus, hedge fund predicts
# 2                                                                                                                                     World Health Organization has distributed 1.5 million coronavirus lab tests around the world
# 3                                                                                                                                  World Health Organization urges "looking after your physical and mental health" during pandemic
# 4                                                                                                                                                                    Michigan suspends non-essential medical and dental procedures
# ..                                                                                                                                                                                                                             ...
# 105                            Los Angeles issued a "Safer at Home" emergency order, meaning residents must "immediately limit all movement outside of their homes beyond what is absolutely essential," Mayor Eric Garcetti said.
# 106                                 "In the last 24 hours, we had 126 new COVID-19 cases, a 21 percent increase. In some parts of our state, our case rate is doubling every four days," Newsom wrote in a letter dated Wednesday.
# 107  Sick patients are being turned away, unable to receive tests because they simply aren't available. In a stark contrast, the NBA said that as of Wednesday, at least eight teams had been tested for the COVID-19 coronavirus.
# 108                                                                                                    While reporting on the pandemic from Beijing for the past eight weeks, CNBC's Eunice Yoon has been living under a lockdown.
# 109                                   The number of infections in New York City jumped by more than 1,000 cases in a matter of hours — since Thursday morning when Gov. Andrew Cuomo said there were 2,469 infections in the city.
#
#                                     0                             1  \
# 0                                 NaN                           NaN
# 1                           (US, GPE)          ($4 trillion, MONEY)
# 2    (World Health Organization, ORG)       (1.5 million, CARDINAL)
# 3    (World Health Organization, ORG)                           NaN
# 4                     (Michigan, GPE)                           NaN
# ..                                ...                           ...
# 105                (Los Angeles, GPE)  (Safer at Home, WORK_OF_ART)
# 106         (the last 24 hours, TIME)               (126, CARDINAL)
# 107                        (NBA, ORG)             (Wednesday, DATE)
# 108                    (Beijing, GPE)  (the past eight weeks, DATE)
# 109              (New York City, GPE)   (more than 1,000, CARDINAL)
#
#                               2                        3                 4  \
# 0                           NaN                      NaN               NaN
# 1                           NaN                      NaN               NaN
# 2                           NaN                      NaN               NaN
# 3                           NaN                      NaN               NaN
# 4                           NaN                      NaN               NaN
# ..                          ...                      ...               ...
# 105     (Eric Garcetti, PERSON)                      NaN               NaN
# 106       (21 percent, PERCENT)  (every four days, DATE)  (Newsom, PERSON)
# 107  (at least eight, CARDINAL)                      NaN               NaN
# 108                 (CNBC, ORG)    (Eunice Yoon, PERSON)               NaN
# 109               (hours, TIME)         (Thursday, DATE)   (morning, TIME)
#
#                           5                  6
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
# ..                      ...                ...
# 105                     NaN                NaN
# 106       (Wednesday, DATE)                NaN
# 107                     NaN                NaN
# 108                     NaN                NaN
# 109  (Andrew Cuomo, PERSON)  (2,469, CARDINAL)
#
# [110 rows x 10 columns]
